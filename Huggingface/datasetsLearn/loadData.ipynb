# %%
from datasets import load_dataset

# %%
dataset = load_dataset('glue', 'mrpc', split='train')
# Out:
# --------------------------------------------------------------------------
# ConnectionError                          Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 dataset = load_dataset('glue', 'mrpc', split='train')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\datasets\load.py:1704, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, **config_kwargs)
#    1701 ignore_verifications = ignore_verifications or save_infos
#    1703 # Create a dataset builder
# -> 1704 builder_instance = load_dataset_builder(
#    1705     path=path,
#    1706     name=name,
#    1707     data_dir=data_dir,
#    1708     data_files=data_files,
#    1709     cache_dir=cache_dir,
#    1710     features=features,
#    1711     download_config=download_config,
#    1712     download_mode=download_mode,
# ...

# %%
dataset
